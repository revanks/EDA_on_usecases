# %% [markdown]
# <a href="https://colab.research.google.com/github/revanks/EDA_on_usecases/blob/main/Car_Price_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import files
iris=files.upload()
# Out:
#      <input type="file" id="files-c91cf08a-6d5b-4c40-9d44-8837f0bb3860" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c91cf08a-6d5b-4c40-9d44-8837f0bb3860">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving car data.csv to car data.csv

# %%
df=pd.read_csv('car data.csv')

# %%
df.shape
# Out:
# (301, 9)

# %%
print(df['Seller_Type'].unique())
print(df['Fuel_Type'].unique())
print(df['Transmission'].unique())
print(df['Owner'].unique())
# Out:
# ['Dealer' 'Individual']
# ['Petrol' 'Diesel' 'CNG']
# ['Manual' 'Automatic']
# [0 1 3]

# %%
##check missing values
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
final_dataset=df[['Year','Selling_Price','Present_Price','Kms_Driven','Fuel_Type','Seller_Type','Transmission','Owner']]

# %%
final_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  ...  Seller_Type Transmission Owner
# 0  2014           3.35           5.59  ...       Dealer       Manual     0
# 1  2013           4.75           9.54  ...       Dealer       Manual     0
# 2  2017           7.25           9.85  ...       Dealer       Manual     0
# 3  2011           2.85           4.15  ...       Dealer       Manual     0
# 4  2014           4.60           6.87  ...       Dealer       Manual     0
#
# [5 rows x 8 columns]

# %%
final_dataset['Current Year']=2020

# %%
final_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  ...  Transmission Owner Current Year
# 0  2014           3.35           5.59  ...        Manual     0         2020
# 1  2013           4.75           9.54  ...        Manual     0         2020
# 2  2017           7.25           9.85  ...        Manual     0         2020
# 3  2011           2.85           4.15  ...        Manual     0         2020
# 4  2014           4.60           6.87  ...        Manual     0         2020
#
# [5 rows x 9 columns]

# %%
final_dataset['no_year']=final_dataset['Current Year']- final_dataset['Year']

# %%
final_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  ...  Owner Current Year no_year
# 0  2014           3.35           5.59  ...      0         2020       6
# 1  2013           4.75           9.54  ...      0         2020       7
# 2  2017           7.25           9.85  ...      0         2020       3
# 3  2011           2.85           4.15  ...      0         2020       9
# 4  2014           4.60           6.87  ...      0         2020       6
#
# [5 rows x 10 columns]

# %%
final_dataset.drop(['Year'],axis=1,inplace=True)

# %%
final_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  ...  Owner Current Year no_year
# 0  2014           3.35           5.59  ...      0         2020       6
# 1  2013           4.75           9.54  ...      0         2020       7
# 2  2017           7.25           9.85  ...      0         2020       3
# 3  2011           2.85           4.15  ...      0         2020       9
# 4  2014           4.60           6.87  ...      0         2020       6
#
# [5 rows x 10 columns]

# %%
final_dataset=pd.get_dummies(final_dataset,drop_first=True)

# %%
final_dataset.head()
# Out:
#    Year  Selling_Price  ...  Seller_Type_Individual  Transmission_Manual
# 0  2014           3.35  ...                       0                    1
# 1  2013           4.75  ...                       0                    1
# 2  2017           7.25  ...                       0                    1
# 3  2011           2.85  ...                       0                    1
# 4  2014           4.60  ...                       0                    1
#
# [5 rows x 11 columns]

# %%
final_dataset.head()
# Out:
#    Year  Selling_Price  ...  Seller_Type_Individual  Transmission_Manual
# 0  2014           3.35  ...                       0                    1
# 1  2013           4.75  ...                       0                    1
# 2  2017           7.25  ...                       0                    1
# 3  2011           2.85  ...                       0                    1
# 4  2014           4.60  ...                       0                    1
#
# [5 rows x 11 columns]

# %%
final_dataset=final_dataset.drop(['Current Year'],axis=1)

# %%
final_dataset.head()
# Out:
#    Year  Selling_Price  ...  Seller_Type_Individual  Transmission_Manual
# 0  2014           3.35  ...                       0                    1
# 1  2013           4.75  ...                       0                    1
# 2  2017           7.25  ...                       0                    1
# 3  2011           2.85  ...                       0                    1
# 4  2014           4.60  ...                       0                    1
#
# [5 rows x 10 columns]

# %%
final_dataset.corr()
# Out:
#                             Year  ...  Transmission_Manual
# Year                    1.000000  ...             0.000394
# Selling_Price           0.236141  ...            -0.367128
# Present_Price          -0.047584  ...            -0.348715
# Kms_Driven             -0.524342  ...            -0.162510
# Owner                  -0.182104  ...            -0.050316
# no_year                -1.000000  ...            -0.000394
# Fuel_Type_Diesel        0.064315  ...            -0.098643
# Fuel_Type_Petrol       -0.059959  ...             0.091013
# Seller_Type_Individual -0.039896  ...             0.063240
# Transmission_Manual     0.000394  ...             1.000000
#
# [10 rows x 10 columns]

# %%
sns.pairplot(final_dataset)

# %%
#get correlations of each features in dataset
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
X=final_dataset.iloc[:,1:]
y=final_dataset.iloc[:,0]

# %%
X['Owner'].unique()
# Out:
# array([0, 1, 3])

# %%
X.head()
# Out:
#    Selling_Price  Present_Price  ...  Seller_Type_Individual  Transmission_Manual
# 0           3.35           5.59  ...                       0                    1
# 1           4.75           9.54  ...                       0                    1
# 2           7.25           9.85  ...                       0                    1
# 3           2.85           4.15  ...                       0                    1
# 4           4.60           6.87  ...                       0                    1
#
# [5 rows x 9 columns]

# %%
y.head()
# Out:
# 0    2014
# 1    2013
# 2    2017
# 3    2011
# 4    2014
# Name: Year, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor
regressor=RandomForestRegressor()
random_forest_model.fit(X_train, y_train)
predict_train_data = random_forest_model.predict(X_train)
predict_test_data = random_forest_model.predict(X_test)

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, predict_test_data))
print('MSE:', metrics.mean_squared_error(y_test, predict_test_data))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predict_test_data)))
# Out:
# MAE: 0.2087912087912088
# MSE: 0.5824175824175825
# RMSE: 0.7631628806602051

# %%
print("The R2 score on the Test set is:\t{:0.3f}".format(metrics.r2_score(y_test, predict_test_data)))
# Out:
# The R2 score on the Test set is:	0.923
